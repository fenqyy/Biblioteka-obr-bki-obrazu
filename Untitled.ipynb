# %%
from Image import *


y = Image('lena.jpg')
x = Image('papyka.jpg')
filtrgorny = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
y.to_gray()
y.threshold(170)
y.show_img()

# %%
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 14.9 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# ...
#      ------------------------------------- 965.4/965.4 kB 20.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 19.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 163.0/163.0 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: A:\Programy\Python\python.exe -m pip install --upgrade pip
